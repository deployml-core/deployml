# %%
import requests

feast_url = "https://feast-server-c5i2hjbjma-wl.a.run.app"

# Test connection
try:
    response = requests.get(f"{feast_url}/health")
    print(f"Status Code: {response.status_code}")
    print(f"Response: {response.text}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Status Code: 200
# Response:
